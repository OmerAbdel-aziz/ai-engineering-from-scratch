# %%
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(0.007187502931281315), np.float64(1.0238348178456185))

# %%
# !uv pip install scikit-learn
# Out:
# Resolved 6 packages in 3.52s
# Prepared 2 packages in 1m 22s
# Installed 5 packages in 47ms
#  + joblib==1.5.3
#  + narwhals==2.22.1
#  + scikit-learn==1.9.0
#  + scipy==1.17.1
#  + threadpoolctl==3.6.0

# %%
# %timeit np.random.randn(10000)
# Out:
# 131 μs ± 2.64 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
